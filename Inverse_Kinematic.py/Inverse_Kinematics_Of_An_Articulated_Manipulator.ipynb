# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando2528/Programacion.Aplicada-Fernando-Andres-Rojas-Fernandez-/blob/main/Inverse_Kinematics_Of_An_Articulated_Manipulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Brazo visto desde arriba
#
# Si elservomotor de la base se implementara se visualizaria el panaroma de la siguiente formar

# %% [markdown]
# ![Perspectiva_Superior.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Donde h seria estaria compuesta por las proyecciones sobre el plano de la extremidades posteriores que conforman el brazo.
#
# Donde $X_{0}$ y $Y_{0}$ representaran la ubicacion del punto final del brazo en el plano XY.
#
# La forma que se utilizara pa representar estas distancias sera la proyeccion de las longitudes sobre el plano en conjunto con $ \theta_{1}$
#
# Siendo $\theta_{1}=\tan^{-1}(\frac{Y_{0}}{X_{0}}) $

# %% [markdown]
# ![Vista_Lateral_Simple.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Para nuestro caso la base no se movera, por ende solo toaremos en cuenta la rotacion de los servomotores principales.
#
# Planteando la situacion donde los angulos de los servomotores son distintos.
#
#
# ![Vista_Lateral_Desglozada.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# $\theta_{2} = \phi_{2} - \phi_{1}$
#
# $\phi = Tg^{-1}(\frac{Z_{x}}{h})$
#
# h previamente se definio como la componente X de los vectores que conforman la estructura del brazo.
#
# Para continuar con el analisis se definiran dos constantes, Logitug del segmento 1 (l1) y Longitud del segmento 2 (l2)
#
# $ $
#
# ##Por ley de cosenos
#
# $(l_{2})^{2} = (l_{1})^{2} + (h_{2})^{2} - 2(l_{1}*h_{2} *\cos{\phi_{1}}) $
#
# $ $
#
# Por tanto $\,\, \phi_{1}= \arccos {\frac{(h_{2})^{2}-(l_{1})^{2}-(l_{2})^{2}}{(-l_{1}*l_{2})}}$
#
# $ $
#
# Para $h_{2}$ es pertinente realizar las siguientes aclaraciones
#
# $h_{2} = [(h)^{2}+(z_{x})^{2}]^{\frac{1}{2}} \,\,\,\, ; \,\,\,\, \theta_{3}=180-\phi_{3}$
#
# $ $
#
# $(h_{2})=(l_{1})^{2}-2*[l_{1}*l_{2}*cos{(\phi_{3}})] $
#
# $ $
#
# $\phi_{3}= \arccos {[\frac{(h_{2})^{2}-(l_{1})^{2}-(l_{2})^{2}}{(-l_{1}*l_{2})}]}$
